# %% [markdown]
# # Integrar Postgres con Python

# %%
import pandas as pd
import psycopg2
import sqlalchemy

import warnings
warnings.filterwarnings(action = "ignore")

# %% [markdown]
# ## Importar datos desde Postgres con Psicorpg2

# %%
# Generar la conexión con la base de datos
conexion = psycopg2.connect(
    host = "localhost",
    port = "5432",
    database = "db_grupo56ds",
    user = "postgres",
    password = "123456"
)

# %%
# Escribir un query
query = "SELECT * FROM vw_empleados"

# %%
# Extraer la información en un dataframe
df_empleados = pd.read_sql(query, con = conexion)

# %%
df_empleados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_completo      15 non-null     object
#  1   usuario_email        15 non-null     object
#  2   departamento         15 non-null     object
#  3   salario              15 non-null     int64
#  4   contrato_permanente  15 non-null     bool
#  5   tiempo_en_empresa    15 non-null     int64
# dtypes: bool(1), int64(2), object(3)
# memory usage: 747.0+ bytes

# %%
# Buena práctica por respecto al Data Manager
conexion.close()

# %% [markdown]
# ## Importar datos desde Postgres con sqlalchemy

# %%
# Crear la conexion
db_config = {
    "host": "localhost", 
    "port": 5432,
    "db": "db_grupo56ds",
    "user": "postgres", 
    "pwd": "123456"
} 

texto_con = "postgresql://{}:{}@{}:{}/{}".format(
    db_config["user"], 
    db_config["pwd"], 
    db_config["host"], 
    db_config["port"], 
    db_config["db"]
)

conexion = sqlalchemy.create_engine(texto_con)

# %%
# Escribir un query
query = "SELECT * FROM vw_consolidada WHERE pais = 'Ecuador'"

# %%
# Extraer los datos
df_visitas = pd.read_sql(query, con = conexion)

# %%
df_visitas.sample(10)
# Out:
#        id_visitas                                                url   hora  \
# 11949     5486710              www.mashpilodge.com/es/reserva-ahora/  23:10
# 2885      5442718  www.mashpilodge.com/es/blog/por-que-es-tan-esp...  09:59
# 12883     5492272  www.mashpilodge.com/es/blog/viaje-a-mashpi-lodge/  20:20
# 15157     5504469  www.mashpilodge.com/es/habitaciones/habitacion...  14:32
# 14600     5501592                               www.mashpilodge.com/  11:43
# 4416      5449117  www.mashpilodge.com/es/habitaciones/habitacion...  14:18
# 7862      5464587  www.mashpilodge.com/es/terminos-condiciones-re...  09:43
# 2043      5436915  www.mashpilodge.com/blog/mashpi-lodge-the-ulti...  18:58
# 2649      5440862  www.mashpilodge.com/es/blog/descubra-el-renova...  18:08
# 13560     5495964                               www.mashpilodge.com/  14:53
#
#        dia                            direccion_ip  duracion_seg  \
# 11949   24   2800:370:127:a990:b4e7:db06:d9f4:9c32    121.736000
# 2885     9    2800:370:12c:6c0:4d97:ddb2:a1c0:40df     30.440000
# 12883   26                           190.63.97.102     17.796999
# 15157   31                         181.198.211.123    178.681500
# 14600   30        2800:430:1286:eb94:1:0:d0e8:11ac     30.440000
# 4416    11                              45.70.58.5     11.253999
# 7862    17                           190.15.137.64     30.440000
# 2043     6  2800:bf0:37c2:10ac:784b:4e74:c724:9f15     18.000000
# 2649     8    2800:bf0:10:111f:7521:d38c:862d:f40c     39.726500
# 13560   28                           190.63.112.30     93.423000
#
#                                            ip     pais  \
# 11949   2800:370:127:a990:b4e7:db06:d9f4:9c32  Ecuador
# 2885     2800:370:12c:6c0:4d97:ddb2:a1c0:40df  Ecuador
# 12883                           190.63.97.102  Ecuador
# 15157                         181.198.211.123  Ecuador
# 14600        2800:430:1286:eb94:1:0:d0e8:11ac  Ecuador
# 4416                               45.70.58.5  Ecuador
# 7862                            190.15.137.64  Ecuador
# 2043   2800:bf0:37c2:10ac:784b:4e74:c724:9f15  Ecuador
# 2649     2800:bf0:10:111f:7521:d38c:862d:f40c  Ecuador
# 13560                           190.63.112.30  Ecuador
#
#                                            direccion_url categoria  \
# 11949              www.mashpilodge.com/es/reserva-ahora/     Motor
# 2885   www.mashpilodge.com/es/blog/por-que-es-tan-esp...      Blog
# 12883  www.mashpilodge.com/es/blog/viaje-a-mashpi-lodge/      Blog
# 15157  www.mashpilodge.com/es/habitaciones/habitacion...  Producto
# 14600                               www.mashpilodge.com/      Home
# 4416   www.mashpilodge.com/es/habitaciones/habitacion...  Producto
# 7862   www.mashpilodge.com/es/terminos-condiciones-re...  Nosotros
# 2043   www.mashpilodge.com/blog/mashpi-lodge-the-ulti...      Blog
# 2649   www.mashpilodge.com/es/blog/descubra-el-renova...      Blog
# 13560                               www.mashpilodge.com/      Home
#
#                             categoria_blog
# 11949                                 None
# 2885                                  Tips
# 12883                                 Tips
# 15157                                 None
# 14600                                 None
# 4416                                  None
# 7862                                  None
# 2043                                  Tips
# 2649   Environmental/Social Responsibility
# 13560                                 None

# %%
# Cerrar la conexion
conexion.dispose()
